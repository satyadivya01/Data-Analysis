# %%
import matplotlib.pyplot as plt

# %%
A = [23,45,67,89,10] #corona cases in first five days
B = [1,2,3,4,5]
plt.plot(B,A) #plot(x,y)
plt.show()

# %%
import numpy as np

# %%
#runs scored by 10 new players [100,50,91,78,89,25,34,19,9,10] wickets taken by same 10 new players [1,0,2,0,3,7,8,9,7,5]
runs=np.array([100,50,91,78,89,25,34,19,9,10])
wickets=np.array([1,0,2,0,3,7,8,9,7,5])
plt.scatter(runs,wickets,color ="m",marker="d")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#plot the scores of two students in 5 subjects ,subjects as x-axis nad marks as y-axis
s1=np.array([86,91,71,97,83])
s2=np.array([90,72,88,92,81])
sub=np.array(["maths","physics","english","social","hindi"])
plt.plot(sub,s1,label="s1")
plt.plot(sub,s2,label="s2")
plt.title("marks v/s subjects")
plt.legend()

# %%
stu1=[56,78,92,95,78]
stu2=[77,89,91,23,45]
sub=["maths","science","english","telugu","social"]
plt.subplot(2,1,1)
plt.plot(sub,stu1,label ="stdent",color ="y")
plt.subplot(2,1,2)
plt.plot(sub,stu2,label ="studend2",color ="m")

# %%
A=np.array([230,560,780,127,128])
B=np.array([200,160,270,127,400])
print("Revenue of company A",A)
print("Revenue of company B",B)
x=np.diff(A)
print("profits of A",x)
y=np.diff(B)
print("profits of B",y)
years=np.array(["2019-2020","2020-2021","2021-2022","2022-2023"])
plt.subplot(1,2,1)
plt.bar(years,x,label="company",color="k")
plt.legend()
plt.subplot(1,2,2)
plt.bar(years,y,label="company2",color="green")
plt.legend()
# Out:
# Revenue of company A [230 560 780 127 128]
# Revenue of company B [200 160 270 127 400]
# profits of A [ 330  220 -653    1]
# profits of B [ -40  110 -143  273]

# %%
a=np.array([25,60,5,10])
labe=["AIML","PYTHON","PANDAS","NUMPY"]
plt.pie(a,labels = labe)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#explode
a = np.array([25,60,5,10])
labe = ["AIML","python","pandas","numpy"]
explo = [0.2,0,0,0]
plt.pie(a,labels =labe,explode = explo,shadow = True)
plt.legend()
plt.show()
